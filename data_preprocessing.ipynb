# %% [markdown]
# <a href="https://colab.research.google.com/github/AMEYABHAVE/Cristl/blob/main/data_preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
import pandas as pd
file_location = '/content/drive/MyDrive/accelerometer.csv'
file_location1 = '/content/drive/MyDrive/gyroscope.csv'
accelerometer =pd.read_csv(file_location)
accelerometer.drop(columns=['time','repetition','uuid'], inplace=True)
gyroscope =pd.read_csv(file_location1)
gyroscope.drop(columns=['time','repetition','uuid'], inplace=True)

# %%
accelerometer.head()
# Out:
#             name     acc_x     acc_y     acc_z activity
# 0  accelerometer -0.414825  7.590469  6.235336    CHAIR
# 1  accelerometer -0.337662  7.645508  6.125275    CHAIR
# 2  accelerometer -0.393295  7.605423  6.231155    CHAIR
# 3  accelerometer -0.469269  7.592865  6.281403    CHAIR
# 4  accelerometer -0.418411  7.633530  6.317307    CHAIR

# %%
gyroscope.head()
# Out:
#         name     gyr_x     gyr_y     gyr_z activity
# 0  gyroscope -0.309540  7.679596  6.142029    CHAIR
# 1  gyroscope -0.530884  7.897354  5.765747    CHAIR
# 2  gyroscope -0.608643  8.231140  5.266846    CHAIR
# 3  gyroscope -0.570953  8.260452  5.229172    CHAIR
# 4  gyroscope -0.816223  8.244308  5.284195    CHAIR

# %%
accchair= accelerometer[accelerometer['activity'] == 'CHAIR']
acccouch= accelerometer[accelerometer['activity'] == 'COUCH']
accsurface= accelerometer[accelerometer['activity'] == 'SURFACE']
acclyingup= accelerometer[accelerometer['activity'] == 'LYING_UP']
acclyingside= accelerometer[accelerometer['activity'] == 'LYING_SIDE']

gyrchair= gyroscope[gyroscope['activity'] == 'CHAIR']
gyrcouch= gyroscope[gyroscope['activity'] == 'COUCH']
gyrsurface= gyroscope[gyroscope['activity'] == 'SURFACE']
gyrlyingup= gyroscope[gyroscope['activity'] == 'LYING_UP']
gyrlyingside= gyroscope[gyroscope['activity'] == 'LYING_SIDE']

# %%
import matplotlib.pyplot as plt
plt.title("SITTING acc_x")
plt.plot(accchair["acc_x"], label="chair")
plt.plot(acccouch["acc_x"], label="couch")
plt.plot(accsurface["acc_x"], label="surface")
plt.legend()
plt.show()

plt.title("SITTING acc_y")
plt.plot(accchair["acc_y"], label="chair")
plt.plot(acccouch["acc_y"], label="couch")
plt.plot(accsurface["acc_y"], label="surface")
plt.legend()
plt.show()

plt.title("SITTING acc_z")
plt.plot(accchair["acc_z"], label="chair")
plt.plot(acccouch["acc_z"], label="couch")
plt.plot(accsurface["acc_z"], label="surface")
plt.legend()
plt.show()

# %%
plt.title("LYING acc_x")
plt.plot(acclyingup["acc_x"], label="Lying Up")
plt.plot(acclyingside["acc_x"], label="Lying Side")
plt.legend()
plt.show()

plt.title("LYING acc_y")
plt.plot(acclyingup["acc_y"], label="Lying Up")
plt.plot(acclyingside["acc_y"], label="Lying Side")
plt.legend()
plt.show()

plt.title("LYING acc_z")
plt.plot(acclyingup["acc_z"], label="Lying Up")
plt.plot(acclyingside["acc_z"], label="Lying Side")
plt.legend()
plt.show()

# %%
plt.title("GYROSCOPE gyr_x")
plt.plot(gyrchair["gyr_x"], label="chair")
plt.plot(gyrcouch["gyr_x"], label="couch")
plt.plot(gyrsurface["gyr_x"], label="surface")
plt.legend()
plt.show()

plt.title("GYROSCOPE gyr_y")
plt.plot(gyrchair["gyr_y"], label="chair")
plt.plot(gyrcouch["gyr_y"], label="couch")
plt.plot(gyrsurface["gyr_y"], label="surface")
plt.legend()
plt.show()

plt.title("GYROSCOPE gyr_z")
plt.plot(gyrchair["gyr_z"], label="chair")
plt.plot(gyrcouch["gyr_z"], label="couch")
plt.plot(gyrsurface["gyr_z"], label="surface")
plt.legend()
plt.show()

# %%
plt.title("LYING gyr_x")
plt.plot(gyrlyingup["gyr_x"], label="Lying Up")
plt.plot(gyrlyingside["gyr_x"], label="Lying Side")
plt.legend()
plt.show()

plt.title("LYING gyr_y")
plt.plot(gyrlyingup["gyr_y"], label="Lying Up")
plt.plot(gyrlyingside["gyr_y"], label="Lying Side")
plt.legend()
plt.show()

plt.title("LYING gyr_z")
plt.plot(gyrlyingup["gyr_z"], label="Lying Up")
plt.plot(gyrlyingside["gyr_z"], label="Lying Side")
plt.legend()
plt.show()
